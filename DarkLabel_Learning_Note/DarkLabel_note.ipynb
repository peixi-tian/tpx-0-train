# %% [markdown]
# # 数据标注工具DarkLabel安装与使用（以及jupyter环境的安装）
# #### （注）部分代码类型的cell中的内容仅用于详细记录过程，不能实际运行

# %% [markdown]
# ### jupyter环境配置

# %% [markdown]
#     笔记本中已提前安装了miniconda，使用anaconda prompt创建新环境，安装jupyter。
#     在D盘中创建目录jupyter_files存放对依赖库要求较低的.ipynb文件，该目录同样用于存放本篇笔记。
#     按win徽标键打开开始菜单，运行anaconda prompt，创建conda环境,安装jupyter和pandas等库，激活环境。
#     切换到D盘中的jupyter_files目录，运行jupyter notebook命令，进入http://localhost:8888/tree?token=619fa413f33d37c86400f20e5e3988c7318755a3a4c3ac82，创建新的.ipynb文件
#     所用命令如下（含盘符及用户名   仅用于详细记录   不可运行）
#
#     C:\Users\红砖墙>conda create -n jupyter_env pandas numpy matplotlib
#     C:\Users\红砖墙>cd /d D:\jupyter_files
#     D:\jupyter_files>conda activate jupyter_env
#     (jupyter_env) jupyter notebook

# %% [markdown]
# ### DarkLabel软件的安装

# %% [markdown]
#     根据研0培训手册所给文章中的超链接，自github下载.zip形式的DarkLabel软件至D盘，软件包含的所有文件如下方第一章图片
#     运行DarkLabel，并尝试进行标注，如下方第二张图片所示（该图片仅用于演示）

# %% [markdown]
# ![darklabel_files.png](attachment:a237da7d-3cb8-40f1-89d5-0eb0483bfe6d.png)

# %% [markdown]
# ![image.png](attachment:ff67c1a9-1dcf-4951-8511-58209e432b8d.png)

# %% [markdown]
# 另外说明，本笔记中使用的conda环境并未安装pytorch深度学习库，将随着学习推进增加相关依赖库，以使用jupyter运行代码的功能。
